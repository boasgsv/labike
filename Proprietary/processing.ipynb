# %% [markdown]
# # Post-Processing of LLM raw outputs to enable performance evaluation

# %%
import pandas as pd
import ast

# %%
raw_output = pd.read_parquet(r'data/raw/outputs.parquet')
raw_output
# Out:
#                   google/gemini-2.5-pro-preview-03-25  \
# 0   {'input': {'doi': '10.1002/cbdv.200800342', 't...
# 1   {'input': {'doi': '10.1093/mutage/gep034', 'te...
# 2   {'input': {'doi': '10.1016/j.phytochem.2008.01...
# 3   {'input': {'doi': '10.1021/np9004079', 'text':...
# 4   {'input': {'doi': '10.1002/ps.1278', 'text': "...
# ..                                                ...
# 5   {'input': {'doi': '10.1055/s-0029-1185364', 't...
# 6   {'input': {'doi': '10.1021/np1007476', 'text':...
# 7   {'input': {'doi': '10.1021/np800612x', 'text':...
# 8   {'input': {'doi': '10.1590/S0103-5053200500080...
# 9   {'input': {'doi': '10.1016/j.cbi.2010.08.008',...
#
#                                        openai/gpt-4.1
# 0   {'input': {'doi': '10.1002/cbdv.200800342', 't...
# 1   {'input': {'doi': '10.1093/mutage/gep034', 'te...
# 2   {'input': {'doi': '10.1016/j.phytochem.2008.01...
# 3   {'input': {'doi': '10.1021/np9004079', 'text':...
# 4   {'input': {'doi': '10.1002/ps.1278', 'text': "...
# ..                                                ...
# 5   {'input': {'doi': '10.1055/s-0029-1185364', 't...
# 6   {'input': {'doi': '10.1021/np1007476', 'text':...
# 7   {'input': {'doi': '10.1021/np800612x', 'text':...
# 8   {'input': {'doi': '10.1590/S0103-5053200500080...
# 9   {'input': {'doi': '10.1016/j.cbi.2010.08.008',...
#
# [143 rows x 2 columns]

# %%
cleaned_outputs = []
models = raw_output.columns.tolist()
for model in models:
    responses = raw_output[model]
    print(f'Cleaning outputs of model {model}...')
    i = 0
    for response in responses:
        i += 1
        if response == '-':
            continue

        output = (
            str(ast.literal_eval(response)['output'])
            .replace('```json', '')
            .replace('```', '')
            .replace('EOF', '')
            .replace('// Cabraleadiol, Ocotillone', '')
            .replace('// Carapa guianensis (Gedunin, 7-Deacetoxy-7-oxogedunin, 6-Acetoxygedunin)', '')
            .replace('// Cedrela odorata, Toona ciliata, Hortia oreadica (exact site not specified, defaulting per known list)', '')
            .replace('Explanation:', '')
            .replace('- The compounds isolated and discussed in this paper do not match any of the compound names from the provided list.', '')
            .replace('- No information on biological activity was reported in the provided text.', '')
            .replace('- Collection species is "Neoraputia alba (Rutaceae)", matching the available options.', '')
            .replace('- Collection type is "Plant Isolated".', '')
            .replace('- Collection site is Espirito Santo, which matches as "N/A/ES".', '')
            .replace("Here's the structured information extracted from the paper:", '')
            
        )
        output_di = ast.literal_eval(output)
        if type(output_di) == list:
            output_di = output_di[0]
        output_di['model'] = model
        cleaned_outputs.append(output_di)

results = pd.DataFrame(cleaned_outputs)
results
# Out:
# Cleaning outputs of model google/gemini-2.5-pro-preview-03-25...
# Cleaning outputs of model openai/gpt-4.1...
#                                  doi  \
# 0             10.1002@cbdv.200800342
# 1              10.1093/mutage/gep034
# 2    10.1016@j.phytochem.2008.01.006
# 3                  10.1021/np9004079
# 4                    10.1002/ps.1278
# ..                               ...
# 281           10.1055/s-0029-1185364
# 282                10.1021/np1007476
# 283                10.1021/np800612x
# 284  10.1590/S0103-50532005000800008
# 285        10.1016/j.cbi.2010.08.008
#
#                                                   name  \
# 0    [Casearin X; (1R*,3S*,5S*,6aR*,7S*,8S*,10R*,10...
# 1                                    [Caseargrewiin F]
# 2    [Pterogynoside; Kaempferol-3-O-(3''-O-4'''-met...
# 3    [Caseobliquin A, Rel-6β-hydroxyzuelanin-2β-ben...
# 4    [2,4,6-trimethoxybenzoic acid, 20-hydroxyecdys...
# ..                                                 ...
# 281  [3,4-dihydro-5-hydroxy-2,7-dimethyl-8-(2"-meth...
# 282                                                 []
# 283                     [Nitensidine D, Nitensidine E]
# 284  [Quercetin-3-O-rutinoside, Kaempferol-3-O-ruti...
# 285  [Casearin X, Casearin L, Casearin O, (-)-Hardw...
#
#                               biological_activity  \
# 0                                     [Cytotoxic]
# 1                          [Mutagenic, Genotoxic]
# 2    [Inhibition of Myeloperoxodase, Antioxidant]
# 3                                     [Cytotoxic]
# 4                                  [Insecticidal]
# ..                                            ...
# 281                 [Antitrypanosomal, Cytotoxic]
# 282                                            []
# 283                       [Cytotoxic, Anticancer]
# 284                                 [Antioxidant]
# 285                       [Cytotoxic, Anticancer]
#
#                                      collection_specie   collection_type  \
# 0               [Casearia sylvestris (Flacourtiaceae)]  [Plant Isolated]
# 1               [Casearia sylvestris (Flacourtiaceae)]  [Plant Isolated]
# 2                        [Pterogyne nitens (Fabaceae)]    Plant Isolated
# 3                  [Casearia obliqua (Flacourtiaceae)]  [Plant Isolated]
# 4    [Vitex polygama (Verbenaceae), Siphoneugena de...  [Plant Isolated]
# ..                                                 ...               ...
# 281               [Peperomia obtusifolia (Piperaceae)]  [Plant Isolated]
# 282                 [Chimarrhis turbinata (Rubiaceae)]  [Plant Isolated]
# 283                      [Pterogyne nitens (Fabaceae)]  [Plant Isolated]
# 284                 [Chimarrhis turbinata (Rubiaceae)]  [Plant Isolated]
# 285             [Casearia sylvestris (Flacourtiaceae)]  [Plant Isolated]
#
#              collection_site                                model
# 0    [Sao Miguel Arcanjo/SP]  google/gemini-2.5-pro-preview-03-25
# 1            [Araraquara/SP]  google/gemini-2.5-pro-preview-03-25
# 2               Sao Paulo/SP  google/gemini-2.5-pro-preview-03-25
# 3              [Campinas/SP]  google/gemini-2.5-pro-preview-03-25
# 4       [Pocos De Caldas/MG]  google/gemini-2.5-pro-preview-03-25
# ..                       ...                                  ...
# 281     [Pocos De Caldas/MG]                       openai/gpt-4.1
# 282               [Belem/PA]                       openai/gpt-4.1
# 283           [Sao Paulo/SP]                       openai/gpt-4.1
# 284               [Belem/PA]                       openai/gpt-4.1
# 285  [Sao Miguel Arcanjo/SP]                       openai/gpt-4.1
#
# [286 rows x 7 columns]

# %% [markdown]
# # We explode the dataset to prepare for hits@k evaluation

# %%
expl_results = (
    results
    [['doi', 'name', 'biological_activity', 'collection_specie', 'collection_type', 'collection_site', 'model']]
    .fillna('[]')
    .explode('name')
    .explode('biological_activity')
    .explode('collection_specie')
    .explode('collection_type')
    .explode('collection_site')
)
expl_results['doi'] = expl_results.doi.astype(str).str.replace('@', '/').str.lower().str.replace('.pdf', '')
expl_results = expl_results[expl_results.doi != '[]']
expl_results
# Out:
#                            doi  \
# 0       10.1002/cbdv.200800342
# 0       10.1002/cbdv.200800342
# 0       10.1002/cbdv.200800342
# 0       10.1002/cbdv.200800342
# 0       10.1002/cbdv.200800342
# ..                         ...
# 285  10.1016/j.cbi.2010.08.008
# 285  10.1016/j.cbi.2010.08.008
# 285  10.1016/j.cbi.2010.08.008
# 285  10.1016/j.cbi.2010.08.008
# 285  10.1016/j.cbi.2010.08.008
#
#                                                   name biological_activity  \
# 0    Casearin X; (1R*,3S*,5S*,6aR*,7S*,8S*,10R*,10a...           Cytotoxic
# 0    Casearin D; (1R*,3S*,5S*,6aR*,7R*,8R*,9S*,10S*...           Cytotoxic
# 0    Casearin L; (1R*,3S*,5S*,6aR*,7R*,8R*,9S*,10S*...           Cytotoxic
# 0    Casearin O; (1R*,3S*,5S*,6aR*,7R*,8R*,9S*,10S*...           Cytotoxic
# 0    Caseargrewiin F; (1R*,3S*,5S*,6aR*,7S*,8R*,10R...           Cytotoxic
# ..                                                 ...                 ...
# 285                                         Casearin L          Anticancer
# 285                                         Casearin O           Cytotoxic
# 285                                         Casearin O          Anticancer
# 285                               (-)-Hardwickiic acid           Cytotoxic
# 285                               (-)-Hardwickiic acid          Anticancer
#
#                         collection_specie collection_type  \
# 0    Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 0    Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 0    Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 0    Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 0    Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# ..                                    ...             ...
# 285  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 285  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 285  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 285  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 285  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
#
#            collection_site                                model
# 0    Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# 0    Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# 0    Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# 0    Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# 0    Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# ..                     ...                                  ...
# 285  Sao Miguel Arcanjo/SP                       openai/gpt-4.1
# 285  Sao Miguel Arcanjo/SP                       openai/gpt-4.1
# 285  Sao Miguel Arcanjo/SP                       openai/gpt-4.1
# 285  Sao Miguel Arcanjo/SP                       openai/gpt-4.1
# 285  Sao Miguel Arcanjo/SP                       openai/gpt-4.1
#
# [3913 rows x 7 columns]

# %% [markdown]
# # We define an ensemble to be the concatenation of both models outputs

# %%
ensemble = expl_results.copy()
ensemble.model = 'ensemble'
ensemble = ensemble.reset_index(drop=True)
final_results = pd.concat([expl_results, ensemble], axis=0)
final_results
# Out:
#                             doi  \
# 0        10.1002/cbdv.200800342
# 0        10.1002/cbdv.200800342
# 0        10.1002/cbdv.200800342
# 0        10.1002/cbdv.200800342
# 0        10.1002/cbdv.200800342
# ...                         ...
# 3908  10.1016/j.cbi.2010.08.008
# 3909  10.1016/j.cbi.2010.08.008
# 3910  10.1016/j.cbi.2010.08.008
# 3911  10.1016/j.cbi.2010.08.008
# 3912  10.1016/j.cbi.2010.08.008
#
#                                                    name biological_activity  \
# 0     Casearin X; (1R*,3S*,5S*,6aR*,7S*,8S*,10R*,10a...           Cytotoxic
# 0     Casearin D; (1R*,3S*,5S*,6aR*,7R*,8R*,9S*,10S*...           Cytotoxic
# 0     Casearin L; (1R*,3S*,5S*,6aR*,7R*,8R*,9S*,10S*...           Cytotoxic
# 0     Casearin O; (1R*,3S*,5S*,6aR*,7R*,8R*,9S*,10S*...           Cytotoxic
# 0     Caseargrewiin F; (1R*,3S*,5S*,6aR*,7S*,8R*,10R...           Cytotoxic
# ...                                                 ...                 ...
# 3908                                         Casearin L          Anticancer
# 3909                                         Casearin O           Cytotoxic
# 3910                                         Casearin O          Anticancer
# 3911                               (-)-Hardwickiic acid           Cytotoxic
# 3912                               (-)-Hardwickiic acid          Anticancer
#
#                          collection_specie collection_type  \
# 0     Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 0     Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 0     Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 0     Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 0     Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# ...                                    ...             ...
# 3908  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 3909  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 3910  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 3911  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
# 3912  Casearia sylvestris (Flacourtiaceae)  Plant Isolated
#
#             collection_site                                model
# 0     Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# 0     Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# 0     Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# 0     Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# 0     Sao Miguel Arcanjo/SP  google/gemini-2.5-pro-preview-03-25
# ...                     ...                                  ...
# 3908  Sao Miguel Arcanjo/SP                             ensemble
# 3909  Sao Miguel Arcanjo/SP                             ensemble
# 3910  Sao Miguel Arcanjo/SP                             ensemble
# 3911  Sao Miguel Arcanjo/SP                             ensemble
# 3912  Sao Miguel Arcanjo/SP                             ensemble
#
# [7826 rows x 7 columns]

# %%
final_results.to_parquet(r'data/processed/final_results.parquet')
